# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
#  ## Trie et préparation des données

# %%
data = {
    "real" : [],
    "user" : [],
    "sys" : []
}

nbFile = []
for i in range(100):
    nbFile.append(30 * (i + 1))

    
with open("data_tf.txt", "r") as f:
    count = 0
    lines = f.readlines()
    

    for line in lines:
        
        line = float(line.split(" ")[1].replace(",", "."))
        if count == 0:
            data["real"].append(line)
            count += 1
            
        elif count == 1:
            data["user"].append(line)
            count += 1
            
        elif count == 2:
            data["sys"].append(line)
            count = 0
            
print(len(nbFile))
print(len(data["sys"]))

data_tf = data
# Out:
# 100
# 100

# %%
# Fonction linéaire
def func(x, a, b, ):
    return a*x + b

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

#Scatter point
color = ["#d90429", "#73ba9b", "#339cff"]
label = ["real", "user", "sys"]
for i in range(len(data)):
    
    ax.scatter(data[label[i]], nbFile, color = color[i], label=label[i])
    
    # Courbe de tendance
    popt, pcov = curve_fit(func, data[label[i]], nbFile)
    ax.plot(data[label[i]], np.polyval(popt, data[label[i]]), '-', label = "Droite de tendance : " + label[i], color = "#212121")

ax.legend()
ax.set(title="Observation des temps de calcul de la commande TF sur des différentes quantités de fichiers", xlabel = "Temps (en seconde)", ylabel = "Nombre de fichier")

fig.savefig("tf.jpg")

# %% [markdown]
# ## Même chose pour DF

# %%
data = {
    "real" : [],
    "user" : [],
    "sys" : []
}

nbFile = []
for i in range(100):
    nbFile.append(30 * (i + 1))

    
with open("data_df.txt", "r") as f:
    count = 0
    lines = f.readlines()
    

    for line in lines:
        
        line = float(line.split(" ")[1].replace(",", "."))
        if count == 0:
            data["real"].append(line)
            count += 1
            
        elif count == 1:
            data["user"].append(line)
            count += 1
            
        elif count == 2:
            data["sys"].append(line)
            count = 0
            
print(len(nbFile))
print(len(data["sys"]))

data_df = data
# Out:
# 100
# 100

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

#Scatter point
color = ["#d90429", "#73ba9b", "#339cff"]
label = ["real", "user", "sys"]
for i in range(len(data)):
    
    ax.scatter(data[label[i]], nbFile, color = color[i], label=label[i])
    
    # Courbe de tendance
    popt, pcov = curve_fit(func, data[label[i]], nbFile)
    ax.plot(data[label[i]], np.polyval(popt, data[label[i]]), '-', label = "Droite de tendance : " + label[i], color = "#212121")

ax.legend()
ax.set(title="Observation des temps de calcul de la commande DF sur des différentes quantités de fichiers", xlabel = "Temps (en seconde)", ylabel = "Nombre de fichier")

fig.savefig("df.jpg")

# %% [markdown]
# ## Calcul TF i DF

# %%
data = {
    "real" : [],
    "user" : [],
    "sys" : []
}

nbFile = []
for i in range(100):
    nbFile.append(30 * (i + 1))

    
with open("data_tfidf.txt", "r") as f:
    count = 0
    lines = f.readlines()
    

    for line in lines:
        
        line = float(line.split(" ")[1].replace(",", "."))
        if count == 0:
            data["real"].append(line)
            count += 1
            
        elif count == 1:
            data["user"].append(line)
            count += 1
            
        elif count == 2:
            data["sys"].append(line)
            count = 0
            
print(len(nbFile))
print(len(data["sys"]))

data_tfidf = data
# Out:
# 100
# 100

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

#Scatter point
color = ["#d90429", "#73ba9b", "#339cff"]
label = ["real", "user", "sys"]
for i in range(len(data)):
    
    ax.scatter(data[label[i]], nbFile, color = color[i], label=label[i])
    
    # Courbe de tendance
    popt, pcov = curve_fit(func, data[label[i]], nbFile)
    ax.plot(data[label[i]], np.polyval(popt, data[label[i]]), '-', label = "Droite de tendance : " + label[i], color = "#212121")

ax.legend()
ax.set(title="Observation des temps de calcul de la commande du TFiDF sur des différentes quantités de fichiers", xlabel = "Temps (en seconde)", ylabel = "Nombre de fichier")

fig.savefig("tfidf.jpg")

# %% [markdown]
# ## Création d'index

# %%
data = {
    "real" : [],
    "user" : [],
    "sys" : []
}

nbFile = []
for i in range(100):
    nbFile.append(30 * (i + 1))

    
with open("data_index.txt", "r") as f:
    count = 0
    lines = f.readlines()
    

    for line in lines:
        
        line = float(line.split(" ")[1].replace(",", "."))
        if count == 0:
            data["real"].append(line)
            count += 1
            
        elif count == 1:
            data["user"].append(line)
            count += 1
            
        elif count == 2:
            data["sys"].append(line)
            count = 0
            
print(len(nbFile))
print(len(data["sys"]))

data_index = data
# Out:
# 100
# 100

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

#Scatter point
color = ["#d90429", "#73ba9b", "#339cff"]
label = ["real", "user", "sys"]
for i in range(len(data)):
    
    ax.scatter(data[label[i]], nbFile, color = color[i], label=label[i])
    
    # Courbe de tendance
    popt, pcov = curve_fit(func, data[label[i]], nbFile)
    ax.plot(data[label[i]], np.polyval(popt, data[label[i]]), '-', label = "Droite de tendance : " + label[i], color = "#212121")

ax.legend()
ax.set(title="Observation des temps de calcul de la commande de création d'un index sur des différentes quantités de fichiers", xlabel = "Temps (en seconde)", ylabel = "Nombre de fichier")

fig.savefig("index.jpg")

# %% [markdown]
# ## Comparaison des temps entre les 3 commandes

# %%
data = {
    "real" : [],
    "user" : [],
    "sys" : []
}

nbFile = []
for i in range(100):
    nbFile.append(30 * (i + 1))

    
with open("data_tfidf.txt", "r") as f:
    count = 0
    lines = f.readlines()
    

    for line in lines:
        
        line = float(line.split(" ")[1].replace(",", "."))
        if count == 0:
            data["real"].append(line)
            count += 1
            
        elif count == 1:
            data["user"].append(line)
            count += 1
            
        elif count == 2:
            data["sys"].append(line)
            count = 0
            
print(len(nbFile))
print(len(data["sys"]))

data_tfidf = data
# Out:
# 100
# 100

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

#Scatter point
color = ["#d90429", "#73ba9b", "#339cff"]
label = ["real", "user", "sys"]
name = ["TF", "DF", "TFiDF"]

data = [data_tf, data_df, data_tfidf]
c = 0

for d in data:
    for i in range(len(d)):

        #ax.scatter(d[label[i]], nbFile, color = color[c], label=name[c] + " " + label[i])

        # Courbe de tendance
        popt, pcov = curve_fit(func, d[label[i]], nbFile)
        ax.plot(d[label[i]], np.polyval(popt, d[label[i]]), '-', label = "Droite de tendance : " + label[i] + " " + name[c], color = color[c])
    c += 1
    
ax.legend()
ax.set(title="Observation des temps de calcul des 3 commandes", xlabel = "Temps (en seconde)", ylabel = "Nombre de fichier")

fig.savefig("3commands.jpg")
